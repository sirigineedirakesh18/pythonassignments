# %% [markdown]
# # PYTHON BASIC ASSIGNMENT -3

# %% [raw]
# 1. Why are functions advantageous to have in your programs?

# %% [raw]
# ANS:
# The main advantage of functions is  they reduce the duplicates of the code by increasing reusability.This makes programs easier to read,easier to update and keeps the code short.

# %% [raw]
# 2. When does the code in a function run: when it's specified or when it's called?

# %% [raw]
# ANS:
# the code in a function doesn't run when it's specified it only runs when it's called.

# %% [raw]
# 3. What statement creates a function?

# %% [raw]
# ANS:
# "def function_name(args):" statement creates the function
# ex:
#  def rakesh(a):
#      pass

# %% [raw]
# 4. What is the difference between a function and a function call?

# %% [raw]
# ANS:
# A function is a piece of code that is used for reusibality and accepts certain parameters to return the result but function call is using the function for returning the result by passing parameters to the function.a function will return the result only if it is called.

# %% [raw]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [raw]
# ANS:
# there is one globoal scope in a function.and the local scope is created whenever a function is called.

# %% [raw]
# 6. What happens to variables in a local scope when the function call returns?

# %% [raw]
# ANS:
# when a function call returns the local scope is destrooyed and all variables of it will be forgotten.whenever we call function again variables will be created again .after returning again the local scope will be destroyed

# %% [raw]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [raw]
# ANS:
# a return value is a value which function returns when it is called.similar to the other values return value can be used in any expression

# %% [raw]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [raw]
# ANS:
# If a function does not have a return statement, then the return value of it is None

# %% [raw]
# 9. How do you make a function variable refer to the global variable?

# %% [raw]
# ANS:
# we can make a function variable refer to the global variable by using global keyword. By using "global" keyword you can use the variable outside the function.

# %% [raw]
# 10. What is the data type of None?

# %% [raw]
# ANS:
# "Nonetype" is the datatype of None

# %% [raw]
# 11. What does the sentence import areallyourpetsnamederic do?

# %% [raw]
# ANS:
# import areallyourpetsnamederic
#
# this sentence will import the module named "areallyourpetsnamederic".

# %% [raw]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [raw]
# ANS:
# for calling bacon feature
#
# import spam
# spam.bacon()

# %% [raw]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [raw]
# ANS:
# when it encounter error,to save the program from crashing we will be using exception handling which contains try block and except block.

# %% [raw]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [raw]
# ANS:the code that can be deployed will go to the try class and the code will be executed if it encounters no error.if the code encounters error it will go to the exception class without crashing the remaining code
