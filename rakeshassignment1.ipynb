# %% [raw]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
#
#
# Ans :
#
# *   is  expressiom
# 'hello' is value
# -87.8  is value
# -  is expression
# /  is expression
# +	 is expression
# 6  is value

# %% [raw]
# 2. What is the difference between string and variable?
#
# ans :
#
# a string is a type of the  variable where as variable is the storage unit of different types such as string,integer,list etc

# %% [raw]
# 3. Describe three different data types.
#
# ans:
#
# integer:
#
# it contains value of positive whole numbers  or negative number (it cannot be decimal or fraction or complex number)
#
# string:
#
# a string is a collection of one or more characters put in a single quotes or double quotes
#
# list:
#
# list is a  collection of data which is mutable and  data need not to be of the same type

# %% [raw]
# 4. What is an expression made up of? What do all expressions do?
#
# ans:
#
# expression is made up of operands and operators combination that is interpreted to produce some other value.in python, expression will be validated according to the precedence of the operators used in it

# %% [raw]
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# ans: while expressions evalute to a value,statement performs action.
#      an expression can be made of several expressions but a statement cannot be made of several statements
#      you cannot do print(spam=10)  but you can do print(10+10)

# %% [raw]
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:
#
# still bacon contain value as 22

# %% [raw]
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# ans:
#
# while printing
#
# 'spam' + 'spamspam'  and  'spam' * 3  will return spamspamspam

# %% [raw]
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# ans: Because a variable name should start with a letter or underscore ,it should not start with number

# %% [raw]
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# ans:
#
# int(),float(),str()

# %% [raw]
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# ans:
#
#     'I have eaten ' + str(99) + ' burritos.'
#     'I have eaten ' + '99'+ ' burritos.'
