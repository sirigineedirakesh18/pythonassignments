# %% [markdown]
# # ASSIGNMENT-5

# %% [raw]
# 1.What does an empty dictionary's code look like?
# ANS:
# dictionary={},dictionary=dict()

# %% [raw]
# 2.what is the value of dictionary value with key 'foo' and the value 42 ?
# ANS:
# {'foo':42}

# %% [raw]
# 3. What is the most significant distinction between a dictionary and a list?
# ANS:
# The elements in dictionary were unordered as well as present in key value pairs where the elements in list are ordered andnot present in key value pairs

# %% [raw]
# 4.What happens if you try to access spam ['foo'] if spam is {'bar':100} ?
# ANS:
# Keyerror will occur

# %%
spam={'bar':100}
spam ['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21480/1227009662.py in <module>
#       1 spam={'bar':100}
# ----> 2 spam ['foo']
#
# KeyError: 'foo'

# %% [raw]
# 5.if a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys() ?
# ANS:
# There is no difference. The in operator checks whether a value exists as a key in the dictionary.

# %% [raw]
# 6.if a dictionary is stored in spam,what is the difference between the expressions 'cat' in spam and 'cat' in spam.values() ?
# ANS:
#  'cat' in spam checks whether "cat" key is present in spam,where as 'cat' in spam.values() will check for "cat" in vslues of the spamm keys

# %% [raw]
# 7.what is a shortcut for the following code ?
# if 'color' not in spam:
#     spam['color'] ='black'
# ANS:
# spam.setdefault('color','black')

# %% [raw]
# 8.How do you 'pretty print' dictionary values using which modules and function ?
# ANS:
# by importing pprint() function from pprint module
# by importing dumps() function from json module
# by importing dumps() function from yaml module
